# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("apple_quality.csv")
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df1=df.drop(columns='A_id')
df1
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# ...

# %%
# df1=df1.drop(4000)
# col=['Size','Weight','Sweetness','Crunchiness','Juiciness','Ripeness','Acidity']
# df1[col]=pd.to_numeric(df[col],errors='coerce')
# newdf=df1[col].fillna(df1[col].mean(),inplace=True)

# %%
df1=df1.dropna()
df1
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# ...

# %%
X=df1.drop(columns=['Quality'])
Y=df1['Quality']
Y
# Out:
# 0       good
# 1       good
# 2        bad
# 3       good
# 4       good
#         ...
# 3995     bad
# 3996    good
# 3997     bad
# 3998    good
# 3999    good
# Name: Quality, Length: 4000, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
#Implementing decision tree
# from sklearn.tree import DecisionTreeClassifier
# decisionmodel=DecisionTreeClassifier()
# decisionmodel.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# decisionmodel.score(X_train,Y_train) #Using decision tree had given us of accuracy 1 which is overfit
# #So decision tree doesn't provided us good accuracy therefore logistic regression is suitable for this model
# Out:
# 1.0

# %%
# decisionmodel.score(X_test,Y_test)
# Out:
# 0.8108333333333333

# %%
#Implementing Linear Regression
from sklearn.linear_model import LogisticRegression
linearmodel=LogisticRegression()
linearmodel.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
linearmodel.score(X_train,Y_train)
# Out:
# 0.7478571428571429

# %%
linearmodel.score(X_test,Y_test)
# Out:
# 0.7466666666666667
